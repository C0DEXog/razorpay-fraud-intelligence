# %% [markdown]
# # Pipeline Reproduction
# Runs the full fraud detection pipeline end-to-end on Razorpay test data.

# %%
# 1. Fetch data
# !python src/data/fetch_razorpay.py 300

# %%
# 2. Train model
# !python src/model/train.py

# %% [markdown]
# # 3. Launch dashboard
# Run `python -m streamlit run app/dashboard.py --server.port 8501` in a separate terminal.
